# %%
import pandas as pd
from sqlalchemy import create_engine, text

# Create Database Connection for Postgres
dbName = 'Hinshaw_Mortgage'
userName = 'postgres'
password = 'password'
engine = create_engine(f"postgresql://{userName}:{password}@localhost/{dbName}")
conn = engine.connect()

# %%
engine.connect()

# %%
pd.read_sql("SELECT * FROM loans LIMIT 5", engine)
# Out:
#    Loan Number Application Date   Lock Date Funding Date  Loan Amount  \
# 0     70000001       2023-01-27  2023-01-30         None       439737
# 1     70000002       2023-03-26  2023-03-31   2023-05-15       621903
# 2     70000003       2023-02-23  2023-02-28         None       580294
# 3     70000004       2023-03-31  2023-04-04   2023-05-25       764044
# 4     70000005       2023-03-20  2023-03-25         None       411397
#
#   Property State Property Type Occupancy Type Loan Purpose    Channel  ...  \
# 0             Tx           Sfr        Primary     Purchase  Wholesale  ...
# 1             Ny           Sfr     Investment     Purchase     Retail  ...
# 2             Ny         Condo        Primary     Purchase     Retail  ...
# 3             Ca           Sfr     Investment     Purchase     Retail  ...
# 4             Va           Sfr     Investment     Purchase     Retail  ...
#
#   Loan Age (Days)  Days To Fund  App To Lock Days  Lock To Fund Days  \
# ...

# %%
pd.read_sql("SELECT * FROM employees LIMIT 5", engine)
# Out:
#    Employee ID First Name  Last Name     Job Title   Region  Branch ID  \
# 0          100     Daniel     Carson  Loan Officer  Midwest         22
# 1          101     Daniel  Hernandez  Loan Officer     East         12
# 2          102     Sophia       Shaw  Loan Officer     West         18
# 3          103    Rebecca  Hernandez  Loan Officer    South         30
# 4          104      Emily     Turner  Loan Officer    South         30
#
#   Branch Location   Hire Date Employment Status Compensation Type  Salary  \
# 0         Chicago  2015-04-05            Active               bps     0.0
# 1       Charlotte  2021-07-02            Active               bps     0.0
# 2     Los Angeles  2020-10-01            Active               bps     0.0
# 3         Atlanta  2015-08-19            Active               bps     0.0
# 4         Atlanta  2017-05-05            Active               bps     0.0
#
#    BPS Compensation Manager ID  Tenure (Years)  Is BPS Compensation  \
# ...

# %%
pd.read_sql("SELECT * FROM extensions LIMIT 5", engine)
# Out:
#    Extension ID  Loan Number  Extension Number Date Extension Requested  \
# 0         90001     70000004                 1               2023-05-02
# 1         90002     70000004                 2               2023-05-15
# 2         90003     70000007                 1               2023-04-22
# 3         90004     70000007                 2               2023-05-10
# 4         90005     70000009                 1               2023-05-10
#
#    Extension (Days)  Extension Cost (%)  Extension Cost ($)  \
# 0                15             0.00250             1910.11
# 1                 5             0.00125              955.06
# 2                15             0.00250             1189.77
# 3                15             0.00250             1189.77
# 4                15             0.00250             1043.73
#
#   Extension Requestor  Approved By (ID) Extension Reason  \
# 0           Processor               126     Title Issues
# ...

# %%
create_view = """
CREATE OR REPLACE VIEW loan_extension_model AS
SELECT
    l."Loan Number" AS loan_number,
    l."Loan Amount" AS loan_amount,
    l."Application Date" AS application_date,
    l."Lock Date" AS lock_date,
    l."Funding Date" AS funding_date,
    l."FICO" AS fico,
    l."DTI" AS dti,
    l."CLTV" AS cltv,
    l."Product Type" AS product_type,
    l."Loan Purpose" AS loan_purpose,
    l."Channel" AS channel,
    l."Property State" AS property_state,
    l."Occupancy Type" AS occupancy_type,
    l."Loan Status" AS loan_status,
    l."Pull Through Flag" AS pull_through_flag,

    lo."Full Name" AS loan_officer,
    lo."Branch Location" AS loan_officer_branch,

    ex."Extension Number" AS extension_number,
    ex."Extension (Days)" AS extension_days,
    ex."Extension Cost ($)" AS extension_fee_amount,
    ex."Date Extension Requested" AS extension_request_date,
    ex."Extension Reason" AS reason_code,
    ex."Total Extension Days" AS total_extension_days,
    ex."Total Extension Cost ($)" AS total_extension_cost,
    ex."Extension Count" AS extension_count,

    approver."Full Name" AS extension_approver

FROM loans l
LEFT JOIN employees lo
    ON l.loan_officer_id = lo."Employee ID"
LEFT JOIN extensions ex
    ON l."Loan Number" = ex."Loan Number"
LEFT JOIN employees approver
    ON ex."Approved By (ID)" = approver."Employee ID";
"""

# %%
with engine.connect() as conn:
    conn.execute(text(create_view))

# %%
pd.read_sql('SELECT * FROM loan_extension_model LIMIT 10', engine)
# Out:
#    loan_number  loan_amount application_date   lock_date funding_date  fico  \
# 0     70000001       439737       2023-01-27  2023-01-30         None   745
# 1     70000002       621903       2023-03-26  2023-03-31   2023-05-15   700
# 2     70000003       580294       2023-02-23  2023-02-28         None   697
# 3     70000004       764044       2023-03-31  2023-04-04   2023-05-25   744
# 4     70000004       764044       2023-03-31  2023-04-04   2023-05-25   744
# 5     70000005       411397       2023-03-20  2023-03-25         None   765
# 6     70000006       389766       2023-03-04  2023-03-09   2023-04-17   757
# 7     70000007       475907       2023-02-23  2023-02-26   2023-04-20   705
# 8     70000007       475907       2023-02-23  2023-02-26   2023-04-20   705
# 9     70000008       367275       2023-02-08  2023-02-11   2023-03-27   641
#
#    dti  cltv  product_type loan_purpose  ... loan_officer_branch  \
# 0   34    92  Conventional     Purchase  ...              Dallas
# ...

# %%
pd.read_sql("SELECT COUNT(*) FROM loan_extension_model;", engine)
# Out:
#    count
# 0  11465
